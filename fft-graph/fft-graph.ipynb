# %% [markdown]
# # Welcome to the FFT Graphing Agent

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from dataclasses import dataclass

filename = "readings.json"

# %% [markdown]
# ## Ingesting JSON payload and ripping data
# picking up a json and ingesting it

# %%
f = open(filename,"r")
data = json.load(f)
print("file contents:")
print(data)

f.close()
# Out:
# file contents:
# [{'Magnitude': 23.419014, 'Phase': -5.14195753e-09, 'Imaginary': -1.20419571e-07, 'Real': 23.419014, 'MagnitudeSquared': 548.4502, 'Sign': {'Magnitude': 1, 'Phase': -5.14195753e-09, 'Imaginary': -5.14195753e-09, 'Real': 1, 'MagnitudeSquared': 1, 'Sign': None}}, {'Magnitude': 0.859045267, 'Phase': -2.51736355, 'Imaginary': -0.5020879, 'Real': -0.6970412, 'MagnitudeSquared': 0.73795867, 'Sign': {'Magnitude': 1, 'Phase': -2.51736355, 'Imaginary': -0.584472, 'Real': -0.8114138, 'MagnitudeSquared': 0.9999999, 'Sign': None}}, {'Magnitude': 0.5053484, 'Phase': 2.62401986, 'Imaginary': 0.2500324, 'Real': -0.4391592, 'MagnitudeSquared': 0.255377, 'Sign': {'Magnitude': 1, 'Phase': 2.62401986, 'Imaginary': 0.494772315, 'Real': -0.869022667, 'MagnitudeSquared': 1, 'Sign': None}}, {'Magnitude': 0.30656606, 'Phase': -3.10456252, 'Imaginary': -0.0113495756, 'Real': -0.3063559, 'MagnitudeSquared': 0.09398275, 'Sign': {'Magnitude': 1, 'Phase': -3.10456252, 'Imaginary': -0.03702163, 'Real': -0.9993144, 'MagnitudeSquared': 0.99999994, 'Sign': None}}, {'Magnitude': 0.389223248, 'Phase': -1.30653358, 'Imaginary': -0.3757115, 'Real': 0.101664193, 'MagnitudeSquared': 0.151494741, 'Sign': {'Magnitude': 1, 'Phase': -1.30653369, 'Imaginary': -0.965285361, 'Real': 0.261197627, 'MagnitudeSquared': 1, 'Sign': None}}, {'Magnitude': 0.3405647, 'Phase': -3.08133078, 'Imaginary': -0.02051063, 'Real': -0.339946479, 'MagnitudeSquared': 0.1159843, 'Sign': {'Magnitude': 1, 'Phase': -3.08133078, 'Imaginary': -0.0602253564, 'Real': -0.998184741, 'MagnitudeSquared': 0.9999999, 'Sign': None}}, {'Magnitude': 0.209970266, 'Phase': -0.893883646, 'Imaginary': -0.163673982, 'Real': 0.131523147, 'MagnitudeSquared': 0.04408751, 'Sign': {'Magnitude': 0.99999994, 'Phase': -0.893883646, 'Imaginary': -0.77951026, 'Real': 0.6263894, 'MagnitudeSquared': 0.99999994, 'Sign': None}}, {'Magnitude': 0.737995, 'Phase': -2.989492, 'Imaginary': -0.1118172, 'Real': -0.729474843, 'MagnitudeSquared': 0.5446366, 'Sign': {'Magnitude': 1, 'Phase': -2.989492, 'Imaginary': -0.151514843, 'Real': -0.988454938, 'MagnitudeSquared': 0.9999999, 'Sign': None}}, {'Magnitude': 0.398327976, 'Phase': -1.53531682, 'Imaginary': -0.398077279, 'Real': 0.0141295139, 'MagnitudeSquared': 0.158665165, 'Sign': {'Magnitude': 1.00000012, 'Phase': -1.53531682, 'Imaginary': -0.9993707, 'Real': 0.03547206, 'MagnitudeSquared': 1.00000012, 'Sign': None}}, {'Magnitude': 1.03823543, 'Phase': -2.41136861, 'Imaginary': -0.6925409, 'Real': -0.77351135, 'MagnitudeSquared': 1.07793272, 'Sign': {'Magnitude': 0.99999994, 'Phase': -2.41136861, 'Imaginary': -0.6670365, 'Real': -0.745025, 'MagnitudeSquared': 0.9999999, 'Sign': None}}, {'Magnitude': 1.29052329, 'Phase': -2.55694056, 'Imaginary': -0.7122517, 'Real': -1.07617271, 'MagnitudeSquared': 1.66545022, 'Sign': {'Magnitude': 1, 'Phase': -2.55694056, 'Imaginary': -0.5519092, 'Real': -0.833904147, 'MagnitudeSquared': 0.9999999, 'Sign': None}}, {'Magnitude': 0.6082279, 'Phase': 1.9780612, 'Imaginary': 0.5584795, 'Real': -0.240918666, 'MagnitudeSquared': 0.369941145, 'Sign': {'Magnitude': 1.00000012, 'Phase': 1.97806108, 'Imaginary': 0.9182077, 'Real': -0.396099359, 'MagnitudeSquared': 1.00000012, 'Sign': None}}, {'Magnitude': 7.55517, 'Phase': -1.54092681, 'Imaginary': -7.55180025, 'Real': 0.225635439, 'MagnitudeSquared': 57.0805969, 'Sign': {'Magnitude': 0.99999994, 'Phase': -1.54092681, 'Imaginary': -0.9995539, 'Real': 0.0298650358, 'MagnitudeSquared': 0.99999994, 'Sign': None}}, {'Magnitude': 1.97452676, 'Phase': 1.72098708, 'Imaginary': 1.95229852, 'Real': -0.295442015, 'MagnitudeSquared': 3.89875555, 'Sign': {'Magnitude': 1.00000012, 'Phase': 1.72098708, 'Imaginary': 0.9887426, 'Real': -0.149626762, 'MagnitudeSquared': 1.00000012, 'Sign': None}}, {'Magnitude': 2.223985, 'Phase': 1.72571838, 'Imaginary': 2.19734955, 'Real': -0.343167633, 'MagnitudeSquared': 4.946109, 'Sign': {'Magnitude': 0.99999994, 'Phase': 1.72571838, 'Imaginary': 0.9880236, 'Real': -0.154303044, 'MagnitudeS ...

# %% [markdown]
# Create collection of complex numbers

# %%
complexNums = []

for element in data:
    newNum = complex(element["Real"], element["Imaginary"])
    complexNums.append(newNum)

print(f"# of items in array: {len(complexNums)}")
# Out:
# size of data array: 392
# # of items in list: 392

# %% [markdown]
# Start Processing to Create Frequency Signal.

# %%
# sampling frequency
# To produce a 10-second wave
length = 10

# assumes sampling stage of 10 seconds
sample_rate = int(len(complexNums)/length)

# Casts the fourier transform coefficients as a numpy array
transformed_y = np.array(complexNums, dtype=complex)

# Take the absolute value of the complex numbers for magnitude spectrum
freq_magnitude = np.abs(transformed_y)

# Create frequency x-axis that will span up to sample_rate
freq_axis = np.linspace(0, sample_rate, len(freq_magnitude))

# Plot frequency domain
plt.plot(freq_axis, freq_magnitude)
plt.xlabel("Frequency (Hz)")
plt.xlim(0, 50)
plt.show()
